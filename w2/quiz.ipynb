# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 1.

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','B'), ('A','C'), ('A','D'), ('A','E'), ('A','F'),
        ('B','C'), ('B','F'), ('C','D'), ('C','F'),
        ('D','E'), ('D','F'),
        ('E','F')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.clustering(g, 'F')
# Out:
# 0.7

# %% [markdown]
# # 2.

# %% [markdown]
# Graph A has higher average LCC but lower trasitivity then graph 'B'

# %% [markdown]
# # 3.

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','B'), ('A','C'),
        ('B','D'),
        ('C','D'), ('C','E'),
        ('D','E'), ('D','G'),
        ('E','G'),
        ('G','F')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.radius(g)
# Out:
# 2

# %%
nx.diameter(g)
# Out:
# 4

# %%
g_noG = g.copy()
g_noG.remove_node('G')
nx.draw_networkx(g_noG)

# %%
nx.is_connected(g_noG)
# Out:
# False

# %%
t = nx.bfs_tree(g, 'A')
nx.draw_networkx(t)

# %%
nx.center(g)
# Out:
# ['D', 'E']

# %%
nx.periphery(g)
# Out:
# ['A', 'F']

# %%
nx.eccentricity(g)
# Out:
# {'A': 4, 'B': 3, 'C': 3, 'D': 2, 'E': 2, 'G': 3, 'F': 4}

# %% [markdown]
# # 4.

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','C'), ('A','D'), ('C','G'), ('G','E'), ('D','E'),
        ('D','B'), ('D','H'), ('E','H'), ('B','H'), ('H','F'),
        ('I','J'), ('I', 'K')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.is_connected(g)
# Out:
# False

# %%
nx.number_connected_components(g)
# Out:
# 2

# %%
g_noEG = g.copy()
g_noEG.remove_edge('E', 'G')
nx.number_connected_components(g_noEG)
# Out:
# 2

# %%
nx.draw_networkx(g_noEG)

# %%
nx.clustering(g, 'I'), nx.clustering(g, 'J'), nx.clustering(g, 'K'),
# Out:
# (0, 0, 0)

# %%
g.add_edge('E', 'J')

# %%
nx.is_connected(g)
# Out:
# True

# %% [markdown]
# # 5.

# %%
g1 = nx.MultiDiGraph()
g2 = nx.MultiDiGraph()
g3 = nx.MultiDiGraph()

# %%
g1.add_edges_from(
    [
        ('',''), ('',''), ('',''), ('',''), ('',''), ('',''),
    ]
)

# %%
g2.add_edges_from(
    [
        ('',''), ('',''), ('',''), ('',''), ('',''), ('',''), ('','')
    ]
)

# %%
g3.add_edges_from(
    [
        ('',''), ('',''), ('',''), ('','')
    ]
)
